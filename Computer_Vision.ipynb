# %% [markdown]
# #Computer Vision - Testing Ground By Kafiling
# Hi I'm trying out comp vision

# %%
import cv2
from matplotlib import pyplot as plt

inputImage = cv2.imread('DSCF5360.JPG')
print(type(inputImage))
# Out:
# <class 'numpy.ndarray'>

# %%
print(inputImage.shape)
# Out:
# (3216, 4288, 3)

# %%
# Open CV collect color as BGR
print(inputImage)
# Out:
# [[[151 106 192]
#   [148 103 189]
#   [147 102 188]
#   ...
#   [ 45  50  95]
#   [ 45  50  95]
#   [ 45  50  95]]
#
#  [[151 106 192]
#   [148 103 189]
#   [145 100 186]
#   ...
#   [ 46  51  96]
#   [ 45  50  95]
#   [ 46  51  96]]
#
#  [[151 106 192]
#   [148 103 189]
#   [145 100 186]
#   ...
#   [ 46  51  96]
#   [ 46  51  96]
#   [ 47  52  97]]
#
#  ...
#
#  [[ 10  26  42]
#   [ 15  31  47]
#   [ 20  39  54]
#   ...
#   [ 59  62 147]
#   [ 57  62 147]
#   [ 59  64 149]]
#
#  [[ 11  27  43]
#   [ 15  31  47]
#   [ 18  37  50]
#   ...
#   [ 60  63 148]
#   [ 58  63 148]
#   [ 60  65 150]]
#
#  [[ 14  30  46]
#   [ 14  30  46]
#   [ 18  37  50]
#   ...
#   [ 61  64 149]
#   [ 61  66 151]
#   [ 58  63 148]]]

# %%
# But plt display using RGB profile -> so img will break
plt.imshow(inputImage)

# %%
inputImageRGB = cv2.cvtColor(inputImage, cv2.COLOR_BGR2RGB)
plt.imshow(inputImageRGB)

# %% [markdown]
# save image

# %%
cv2.imwrite('output.jpg', inputImage)
# Out:
# True

# %%
inputImageCir = cv2.imread('DSCF5360.JPG')
inputImageRGBCir = cv2.cvtColor(inputImageCir, cv2.COLOR_BGR2RGB)

image = cv2.circle(inputImageRGBCir,(1250,1250),1500,(250,0,0),20)

# %%
plt.imshow(image)
